# %%
import re

import matplotlib.pyplot as plt
import nltk
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from keras.layers import Dense, Activation, Dropout
from keras.utils import np_utils
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from spacy.lang.en import English
from tensorflow.keras.models import Sequential

nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to C:\Users\Dage
# [nltk_data]     Zhu\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
parent_df = pd.read_csv("parent_reply.csv", sep=',')
talking_head_df = pd.read_csv("talking_head.csv", sep=',')

# %%
parent_df.head()
# Out:
#    parent_id                                      parent  \
# 0          0    Oh, I told you. I couldn’t close it. So…
# 1          1  Actually, you called me in here, but yeah.
# 2          2                         Well. I don’t know.
# 3          3                                       What?
# 4          4                       Uh, yeah. Just a fax.
#
#                                                reply character
# 0  So you’ve come to the master for guidance? Is ...   Michael
# 1    All right. Well, let me show you how it’s done.   Michael
# 2  If you think she’s cute now, you should have s...   Michael
# 3                                      Any messages?   Michael
# 4  Oh! Pam, this is from Corporate. How many time...   Michael

# %%
talking_head_df.head()
# Out:
#    quote_id                                              quote character
# 0         0  Yes, I’d like to speak to your office manager,...   Michael
# 1         1  People say I am the best boss. They go, “God w...   Michael
# 2         2  Corporate really doesn’t really interfere with...   Michael
# 3         3  Am I going to tell them? No, I am not going to...   Michael
# 4         4  I think I’m a role model here. I think I garne...   Michael

# %%
df1 = talking_head_df[['quote', 'character']]
df2 = parent_df[['reply', 'character']]
df2.columns = ['quote', 'character']
df = pd.concat([df1, df2], ignore_index=True)
plt.figure(figsize=(8, 3))
df['character'].value_counts(normalize=True).plot(kind='bar')
plt.show()

# %%
df.head()
# Out:
#                                                quote character
# 0  Yes, I’d like to speak to your office manager,...   Michael
# 1  People say I am the best boss. They go, “God w...   Michael
# 2  Corporate really doesn’t really interfere with...   Michael
# 3  Am I going to tell them? No, I am not going to...   Michael
# 4  I think I’m a role model here. I think I garne...   Michael

# %%
porter_stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()
nlp = English()

# %%
# to lower case
df.quote = df.quote.apply(lambda s: s.lower() if type(s) == str else s)
# remove digits
df.replace('\d+', '', regex=True, inplace=True)
# remove punctuation marks
df.quote = df.quote.apply(lambda s: re.sub(r'[^\w\s]', '', s))
# remove superfluous blanks
df.quote = df.quote.apply(lambda s: re.sub(' +', ' ', s))
# tokenization
df.quote = df.quote.apply(lambda column: word_tokenize(column))
# remove stopwords
df.quote = df.quote.apply(lambda x: ' '.join([token for token in x if not nlp.vocab[token].is_stop]))
# normalizing words
df.quote = df.quote.apply(lambda x: ' '.join([porter_stemmer.stem(token) for token in x.split()]))
# lemmatization
df.quote = df.quote.apply(lambda x: ' '.join([lemmatizer.lemmatize(token) for token in x.split()]))
df
# Out:
#                                                    quote character
# 0      ye id like speak offic manag ye hello michael ...   Michael
# 1      peopl best bos god weve work place like your h...   Michael
# 2      corpor doesnt interfer jan levinson gould jan ...   Michael
# 3      go tell go tell dont point doctor tell patient...   Michael
# 4      think im role model think garner peopl respect...   Michael
# ...                                                  ...       ...
# 27894                                               gift       Pam
# 27895                                              ahead       Pam
# 27896                                               yeah       Pam
# 27897                                               what       Pam
# 27898                                              thank       Pam
#
# [27899 rows x 2 columns]

# %%
X = df.quote
y = df.character
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=True)
# Create dictionary and transform to feature vectors.
count_vector = CountVectorizer(stop_words='english', max_features=10000)
X_train_counts = count_vector.fit_transform(X_train).toarray()

# %%
# Create test documents and vectorize.
X_test_counts = count_vector.transform(X_test).toarray()

# %% [markdown]
# # Multinomial Naive Bayes

# %%
# Create model(naive bayes) and training.
clf = MultinomialNB()

# %%
clf.fit(X_train_counts, y_train)
clf.score(X_test_counts, y_test)
# Out:
# 0.42141848593461495

# %%
ConfusionMatrixDisplay.from_estimator(clf, X_test_counts, y_test)

# %% [markdown]
# # Gaussian Naive Bayes

# %%
# Create model(naive bayes) and training.
clf = GaussianNB()
clf.fit(X_train_counts, y_train)
clf.score(X_test_counts, y_test)
ConfusionMatrixDisplay.from_estimator(clf, X_test_counts, y_test)

# %% [markdown]
# # KNN

# %%
clf = KNeighborsClassifier(n_neighbors=4)
clf.fit(X_train_counts, y_train)
clf.score(X_test_counts, y_test)
ConfusionMatrixDisplay.from_estimator(clf, X_test_counts, y_test)

# %% [markdown]
# # ANN

# %%
model = Sequential()
model.add(Dense(512, input_shape=(8373,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(4))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

# %%
encoder = LabelEncoder()
encoder.fit(y_train)
y_train = encoder.transform(y_train)
y_train = np_utils.to_categorical(y_train, 4)
y_test = encoder.transform(y_test)
y_test = np_utils.to_categorical(y_test, 4)
history = model.fit(X_train_counts, y_train, epochs=250, batch_size=32, verbose=2, callbacks=[callback],
                    validation_split=0.2)
# Out:
# Epoch 1/250
# 468/468 - 7s - loss: 1.2874 - accuracy: 0.3967 - val_loss: 1.2539 - val_accuracy: 0.4178 - 7s/epoch - 15ms/step
# Epoch 2/250
# 468/468 - 6s - loss: 1.1212 - accuracy: 0.5050 - val_loss: 1.2801 - val_accuracy: 0.4137 - 6s/epoch - 14ms/step
# Epoch 3/250
# 468/468 - 6s - loss: 0.9680 - accuracy: 0.5845 - val_loss: 1.3265 - val_accuracy: 0.4143 - 6s/epoch - 14ms/step
# Epoch 4/250
# 468/468 - 6s - loss: 0.8447 - accuracy: 0.6379 - val_loss: 1.3994 - val_accuracy: 0.4036 - 6s/epoch - 14ms/step
# Epoch 5/250
# 468/468 - 6s - loss: 0.7537 - accuracy: 0.6759 - val_loss: 1.4765 - val_accuracy: 0.4137 - 6s/epoch - 14ms/step
# Epoch 6/250
# 468/468 - 6s - loss: 0.6875 - accuracy: 0.7058 - val_loss: 1.5570 - val_accuracy: 0.3993 - 6s/epoch - 14ms/step
# Epoch 7/250
# 468/468 - 6s - loss: 0.6355 - accuracy: 0.7283 - val_loss: 1.6290 - val_accuracy: 0.4060 - 6s/epoch - 14ms/step
# Epoch 8/250
# 468/468 - 7s - loss: 0.5984 - accuracy: 0.7424 - val_loss: 1.6962 - val_accuracy: 0.3980 - 7s/epoch - 14ms/step
# Epoch 9/250
# 468/468 - 6s - loss: 0.5667 - accuracy: 0.7546 - val_loss: 1.7538 - val_accuracy: 0.3937 - 6s/epoch - 14ms/step
# Epoch 10/250
# 468/468 - 6s - loss: 0.5471 - accuracy: 0.7642 - val_loss: 1.8266 - val_accuracy: 0.4068 - 6s/epoch - 14ms/step
# Epoch 11/250
# 468/468 - 6s - loss: 0.5272 - accuracy: 0.7697 - val_loss: 1.8788 - val_accuracy: 0.3921 - 6s/epoch - 14ms/step
# Epoch 12/250
# 468/468 - 6s - loss: 0.5106 - accuracy: 0.7802 - val_loss: 1.9309 - val_accuracy: 0.3875 - 6s/epoch - 14ms/step
# Epoch 13/250
# 468/468 - 6s - loss: 0.4962 - accuracy: 0.7826 - val_loss: 2.0135 - val_accuracy: 0.3932 - 6s/epoch - 14ms/step
# Epoch 14/250
# 468/468 - 6s - loss: 0.4834 - accuracy: 0.7892 - val_loss: 2.0576 - val_accuracy: 0.3932 - 6s/epoch - 14ms/step
# Epoch 15/250
# 468/468 - 6s - loss: 0.4779 - accuracy: 0.7889 - val_loss: 2.0963 - val_accuracy: 0.3958 - 6s/epoch - 14ms/step
# Epoch 16/250
# 468/468 - 7s - loss: 0.4662 - accuracy: 0.7935 - val_loss: 2.1623 - val_accuracy: 0.3926 - 7s/epoch - 14ms/step
# Epoch 17/250
# 468/468 - 6s - loss: 0.4622 - accuracy: 0.7940 - val_loss: 2.2166 - val_accuracy: 0.3940 - 6s/epoch - 14ms/step
# Epoch 18/250
# 468/468 - 7s - loss: 0.4532 - accuracy: 0.8002 - val_loss: 2.2425 - val_accuracy: 0.3980 - 7s/epoch - 14ms/step
# Epoch 19/250
# 468/468 - 6s - loss: 0.4482 - accuracy: 0.7994 - val_loss: 2.2965 - val_accuracy: 0.3897 - 6s/epoch - 14ms/step
# Epoch 20/250
# 468/468 - 6s - loss: 0.4456 - accuracy: 0.7988 - val_loss: 2.3415 - val_accuracy: 0.3964 - 6s/epoch - 14ms/step
# Epoch 21/250
# 468/468 - 6s - loss: 0.4369 - accuracy: 0.8059 - val_loss: 2.3970 - val_accuracy: 0.3822 - 6s/epoch - 14ms/step
# Epoch 22/250
# 468/468 - 6s - loss: 0.4319 - accuracy: 0.8038 - val_loss: 2.4338 - val_accuracy: 0.3934 - 6s/epoch - 14ms/step
# Epoch 23/250
# 468/468 - 6s - loss: 0.4296 - accuracy: 0.8039 - val_loss: 2.4840 - val_accuracy: 0.3899 - 6s/epoch - 14ms/step
# Epoch 24/250
# 468/468 - 6s - loss: 0.4295 - accuracy: 0.8039 - val_loss: 2.5155 - val_accuracy: 0.3894 - 6s/epoch - 14ms/step
# Epoch 25/250
# 468/468 - 6s - loss: 0.4218 - accuracy: 0.8097 - val_loss: 2.5739 - val_accuracy: 0.3891 - 6s/epoch - 14ms/step
# Epoch 26/250
# 468/468 - 6s - loss: 0.4215 - accuracy: 0.8087 - val_loss: 2.6059 - val_accuracy: 0.3915 - 6s/epoch - 14ms/step
# Epoch 27/250
# 468/468 - 7s - loss: 0.4175 - accuracy: 0.8081 - val_loss: 2.6550 - val_accuracy: 0.3948 - 7s/epoch - 14ms/step
# Epoch 28/250
# 468/468 - 6s - loss: 0.4146 - accuracy: 0.8085 - val_loss: 2.6927 - val_accuracy: 0.3881 - 6s/epoch - 14ms/step
# Epoch 29/250
# 468/468 - 6s - loss: 0.4123 - accuracy: 0.8089 - val_loss: 2.7198 - val_accuracy: 0.3875 - 6s/epoch - 14ms/step
# Epoch 30/250
# 468/468 - 7s - loss: 0.4128 - accuracy: 0.8075 - val_loss: 2.7726 - val_accuracy: 0.3907 - 7s/epoch - 14ms/step
# Epoch 31/250
# 468/468 - 6s - loss: 0.4091 - accuracy: 0.8108 - val_loss: 2.8082 - val_accuracy: 0.3891 - 6s/epoch - 14ms/step
# Epoch 32/250
# 468/468 - 6s - loss: 0.4070 - accuracy: 0.8113 - val_loss: 2.8620 - val_accuracy: 0.3932 - 6s/epoch - 14ms/step
# Epoch 33/250
# 468/468 - 6s - loss: 0.4051 - accuracy: 0.8108 - val_loss: 2.8795 - val_accuracy: 0.3940 - 6s/epoch - 14ms/step
# Epoch 34/250
# 468/468 - 6s - loss: 0.4041 - accuracy: 0.8095 - val_loss: 2.9301 - val_accuracy: 0.3905 - 6s/epoch - 14ms/step
# Epoch 35/250
# 468/468 - 6s - loss: 0.4006 - accuracy: 0.8156 - val_loss: 2.9755 - val_accuracy: 0.3948 - 6s/epoch - 14ms/step
# Epoch 36/250
# 468/468 - 7s - loss: 0.4002 - accuracy: 0.8121 - val_loss: 3.0313 - val_accuracy: 0.3945 - 7s/epoch - 14ms/step
# Epoch 37/250
# 468/468 - 6s - loss: 0.3967 - accuracy: 0.8144 - val_loss: 3.0608 - val_accuracy: 0.3918 - 6s/epoch - 14ms/step
# Epoch 38/250
# 468/468 - 6s - loss: 0.3970 - accuracy: 0.8153 - val_loss: 3.0921 - val_accuracy: 0.3958 - 6s/epoch - 14ms/step
# Epoch 39/250
# 468/468 - 6s - loss: 0.3962 - accuracy: 0.8135 - val_loss: 3.1576 - val_accuracy: 0.3894 - 6s/epoch - 14ms/step
# Epoch 40/250
# 468/468 - 6s - loss: 0.3927 - accuracy: 0.8157 - val_loss: 3.1748 - val_accuracy: 0.3899 - 6s/epoch - 14ms/step
# Epoch 41/250
# 468/468 - 6s - loss: 0.3932 - accuracy: 0.8146 - val_loss: 3.1853 - val_accuracy: 0.3958 - 6s/epoch - 14ms/step
# Epoch 42/250
# 468/468 - 6s - loss: 0.3891 - accuracy: 0.8181 - val_loss: 3.2352 - val_accuracy: 0.3899 - 6s/epoch - 14ms/step
# Epoch 43/250
# 468/468 - 6s - loss: 0.3908 - accuracy: 0.8142 - val_loss: 3.2673 - val_accuracy: 0.3915 - 6s/epoch - 14ms/step
# Epoch 44/250
# 468/468 - 6s - loss: 0.3889 - accuracy: 0.8170 - val_loss: 3.3054 - val_accuracy: 0.3894 - 6s/epoch - 14ms/step
# Epoch 45/250
# 468/468 - 7s - loss: 0.3910 - accuracy: 0.8168 - val_loss: 3.3262 - val_accuracy: 0.3897 - 7s/epoch - 14ms/step
# Epoch 46/250
# 468/468 - 6s - loss: 0.3849 - accuracy: 0.8191 - val_loss: 3.3773 - val_accuracy: 0.3859 - 6s/epoch - 14ms/step
# Epoch 47/250
# 468/468 - 6s - loss: 0.3863 - accuracy: 0.8197 - val_loss: 3.3855 - val_accuracy: 0.3849 - 6s/epoch - 14ms/step
# Epoch 48/250
# 468/468 - 6s - loss: 0.3855 - accuracy: 0.8164 - val_loss: 3.4239 - val_accuracy: 0.3897 - 6s/epoch - 14ms/step
# Epoch 49/250
# 468/468 - 6s - loss: 0.3839 - accuracy: 0.8184 - val_loss: 3.4533 - val_accuracy: 0.3902 - 6s/epoch - 14ms/step
# Epoch 50/250
# 468/468 - 6s - loss: 0.3840 - accuracy: 0.8204 - val_loss: 3.4958 - val_accuracy: 0.3937 - 6s/epoch - 14ms/step
# Epoch 51/250
# 468/468 - 6s - loss: 0.3817 - accuracy: 0.8196 - val_loss: 3.5257 - val_accuracy: 0.3878 - 6s/epoch - 14ms/step
# Epoch 52/250
# 468/468 - 6s - loss: 0.3800 - accuracy: 0.8190 - val_loss: 3.5693 - val_accuracy: 0.3865 - 6s/epoch - 14ms/step
# Epoch 53/250
# 468/468 - 6s - loss: 0.3833 - accuracy: 0.8180 - val_loss: 3.5914 - val_accuracy: 0.3905 - 6s/epoch - 14ms/step
# Epoch 54/250
# 468/468 - 7s - loss: 0.3811 - accuracy: 0.8215 - val_loss: 3.6196 - val_accuracy: 0.3905 - 7s/epoch - 14ms/step
# Epoch 55/250
# 468/468 - 7s - loss: 0.3830 - accuracy: 0.8189 - val_loss: 3.6536 - val_accuracy: 0.3934 - 7s/epoch - 14ms/step
# Epoch 56/250
# 468/468 - 6s - loss: 0.3781 - accuracy: 0.8192 - val_loss: 3.6661 - val_accuracy: 0.3851 - 6s/epoch - 14ms/step
# Epoch 57/250
# 468/468 - 6s - loss: 0.3779 - accuracy: 0.8205 - val_loss: 3.6880 - val_accuracy: 0.3894 - 6s/epoch - 14ms/step
# Epoch 58/250
# 468/468 - 6s - loss: 0.3798 - accuracy: 0.8166 - val_loss: 3.7220 - val_accuracy: 0.3905 - 6s/epoch - 14ms/step
# Epoch 59/250
# 468/468 - 6s - loss: 0.3763 - accuracy: 0.8205 - val_loss: 3.7499 - val_accuracy: 0.3934 - 6s/epoch - 14ms/step
# Epoch 60/250
# 468/468 - 6s - loss: 0.3759 - accuracy: 0.8198 - val_loss: 3.7784 - val_accuracy: 0.3910 - 6s/epoch - 14ms/step
# Epoch 61/250
# 468/468 - 6s - loss: 0.3745 - accuracy: 0.8217 - val_loss: 3.8320 - val_accuracy: 0.3907 - 6s/epoch - 14ms/step
# Epoch 62/250
# 468/468 - 6s - loss: 0.3763 - accuracy: 0.8212 - val_loss: 3.8263 - val_accuracy: 0.3886 - 6s/epoch - 14ms/step
# Epoch 63/250
# 468/468 - 7s - loss: 0.3806 - accuracy: 0.8199 - val_loss: 3.8574 - val_accuracy: 0.3891 - 7s/epoch - 14ms/step
# Epoch 64/250
# 468/468 - 7s - loss: 0.3736 - accuracy: 0.8229 - val_loss: 3.8931 - val_accuracy: 0.3907 - 7s/epoch - 14ms/step
# Epoch 65/250
# 468/468 - 6s - loss: 0.3741 - accuracy: 0.8198 - val_loss: 3.9357 - val_accuracy: 0.3907 - 6s/epoch - 14ms/step
# Epoch 66/250
# 468/468 - 6s - loss: 0.3735 - accuracy: 0.8222 - val_loss: 3.9489 - val_accuracy: 0.3921 - 6s/epoch - 14ms/step
# Epoch 67/250
# 468/468 - 6s - loss: 0.3742 - accuracy: 0.8221 - val_loss: 3.9962 - val_accuracy: 0.3958 - 6s/epoch - 14ms/step
# Epoch 68/250
# 468/468 - 6s - loss: 0.3696 - accuracy: 0.8240 - val_loss: 4.0142 - val_accuracy: 0.3859 - 6s/epoch - 14ms/step
# Epoch 69/250
# 468/468 - 6s - loss: 0.3712 - accuracy: 0.8220 - val_loss: 4.0233 - val_accuracy: 0.3934 - 6s/epoch - 14ms/step
# Epoch 70/250
# 468/468 - 6s - loss: 0.3718 - accuracy: 0.8211 - val_loss: 4.0362 - val_accuracy: 0.3940 - 6s/epoch - 14ms/step
# Epoch 71/250
# 468/468 - 6s - loss: 0.3705 - accuracy: 0.8222 - val_loss: 4.0614 - val_accuracy: 0.3870 - 6s/epoch - 14ms/step
# Epoch 72/250
# 468/468 - 6s - loss: 0.3709 - accuracy: 0.8227 - val_loss: 4.0760 - val_accuracy: 0.3881 - 6s/epoch - 14ms/step
# Epoch 73/250
# 468/468 - 7s - loss: 0.3707 - accuracy: 0.8251 - val_loss: 4.1233 - val_accuracy: 0.3894 - 7s/epoch - 14ms/step

# %%
plt.figure(0)

plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()

plt.figure(1)
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()

# confusion matrix
# Predict the values from the validation dataset
Y_pred = model.predict(X_test_counts)
# Convert predictions classes to one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis=1)
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_test, axis=1)
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)
# plot the confusion matrix
f, ax = plt.subplots(figsize=(8, 8))
sns.heatmap(confusion_mtx, annot=True, linewidths=0.01, cmap="Greens", linecolor="gray", fmt='.1f', ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# test
# Out:
# 288/288 [==============================] - 1s 4ms/step
